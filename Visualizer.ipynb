# %%
import numpy as np
X = np.load('skeleton_train_xsub_fixed.npy')

# %%
X.shape
# Out:
# (31772, 300, 25, 3)

# %%
test = X[554][100]

# %%
import numpy as np
import pylab as plt


def skeletonPlot(arr):
    body = np.swapaxes(np.array([arr[0],arr[1],arr[20],arr[2],arr[3]]),0,1)
    
    l_leg =   np.swapaxes(np.array([arr[19],arr[18],arr[17],arr[16],arr[0] ]),0,1)
    r_leg =  np.swapaxes(np.array([arr[15],arr[14],arr[13],arr[12],arr[0]]) ,0,1)
    
    l_arm =np.swapaxes( np.array([arr[20],arr[8],arr[9],arr[10] ] )   ,0,1)
    r_arm = np.swapaxes( np.array([arr[20],arr[4],arr[5],arr[6]])    ,0,1)
    
    l_hand = np.swapaxes(np.array([arr[7],arr[21],arr[22]])    ,0,1)
    r_hand = np.swapaxes(np.array([arr[11],arr[23],arr[24]])  ,0,1)
    
    head = np.swapaxes(np.array([arr[3]]),0,1) 

    fig, ax = plt.subplots()
    ax.axis([-1, 1, -1, 1])
    ax.plot(body[0],body[1],'.-')
    ax.plot(l_leg[0],l_leg[1],'.-')
    ax.plot(r_leg[0],r_leg[1],'.-')
    ax.plot(l_arm[0],l_arm[1],'.-')
    ax.plot(r_arm[0],r_arm[1],'.-')
    ax.plot(l_hand[0],l_hand[1],'.')
    ax.plot(r_hand[0],r_hand[1],'.')
    ax.plot(head[0],head[1],'ro',markersize=20)
    plt.show()

# %%
skeletonPlot(test)

# %%
for k in X:
    for c in k:
        skeletonPlot(c)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-ab2a660a5923> in <module>
#       1 for k in X:
#       2     for c in k:
# ----> 3         skeletonPlot(c)
#
# <ipython-input-83-a22b1c4283cb> in skeletonPlot(arr)
#      27     ax.plot(r_hand[0],r_hand[1],'.')
#      28     ax.plot(head[0],head[1],'ro',markersize=20)
# ---> 29     plt.show()
#      30
#      31
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ...
